# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)]
# (https://colab.research.google.com/github/shaevitz/MOL518-Intro-to-Data-Analysis/blob/main/lectures/lecture01.ipynb)

# %%
# Clone the full course repository
# !git clone https://github.com/shaevitz/MOL518-Intro-to-Data-Analysis.git

# Move into the repo so relative paths work
# %cd MOL518-Intro-to-Data-Analysis

# %% [markdown]
# # Lecture 1: Python, Jupyter, Colab, and the Programming Mindset
#
# <p align="center">
# <img src="media/ProgrammingLogos.png" alt="Logos" width="600" />
# </p>
#
# In this class, we will learn to code in Python using Jupyter Notebooks running in Google Colab. These notebooks let us combine code, explanatory text, figures, and results in a single, readable document, which makes them well suited for learning, exploration, and real data analysis.
#
# The goals of this lecture are to
# 1.	Understand what Python, Jupyter Notebooks, and Google Colab are and how they fit together.
# 2.	Learn how to work in a notebook, including editing cells and using both code and Markdown text.
# 3.	Begin developing the habit of thinking like a computer so that you can design clear, explicit algorithms.
# 4.	Take first steps toward loading data, plotting results, using AI tools productively, and debugging when things go wrong.

# %% [markdown]
# ## Data Analysis is an Integral Part of the Scientific Process
#
# <p align="center">
# <img src="media/ScientificCycle.png" alt="Scientific Cycle" width="400" />
# </p>
#
# - Modern science is an iterative cycle, not a straight line from question to answer.
# - Hypotheses motivate experimental design, which leads to data acquisition.
# - **Data analysis sits at the same level as these steps**, shaping what we see, what we trust, and what we do next.
# - Analysis transforms raw measurements into structure, patterns, and quantitative comparisons.
# - The results of analysis inform interpretation, refine hypotheses, and often drive new experiments.
# - Because analysis feeds back into every other stage, it is not a final step but a continuous partner in scientific reasoning.

# %% [markdown]
# ## What is Python?
#
# - Python is a programming language we will use to analyze data, build simple models, and make quantitative plots.
# - It is a way of giving a computer **precise, explicit instructions**. Computers are fast and reliable, but they do exactly what you tell them to do.
# - Learning Python is therefore about learning how to **think step by step** and translate ideas into clear procedures.
# - Python is widely used in biology, physics, and data science because it is readable, flexible, and supported by powerful scientific libraries.
# - In this course, we will use Python to load real biological data, perform calculations, and visualize results.
# - No prior programming experience is expected. We will build concepts gradually and focus on understanding what each line of code does.

# %% [markdown]
# ## Why We Use Notebooks in Scientific Computing
#
# - Scientific work is rarely linear. We try an idea, look at the result, notice something unexpected, and change course.
# - Analysis usually cycles through loading data, exploring it, visualizing patterns, revising assumptions, and repeating the process.
# - A notebook keeps **code, text, equations, figures, and results together** in the order you actually thought about them.
# - This makes your work easier to understand later, both for you and for others, because the reasoning sits next to the computation.
# - Notebooks are especially well suited for exploratory data analysis, model development, and teaching, where insight comes from iterating rather than running a single finished script.
# - Many researchers do most of their real analysis in notebooks, even when final results are later packaged into scripts or papers.

# %% [markdown]
# ## Jupyter vs Google Colab
#
# Jupyter notebooks are not meant to be opened as plain text. They contain structured information that only a notebook interface can interpret, display, and run as Python code.
#
# ### Jupyter
# - Runs locally or on a remote server (like Princeton OIT's myDella).
# - Full control over environment.
# - Ideal for long term research projects.
#
# ### Google Colab
# - No installation needed.
# - Saves work to Google Drive.
# - Good for learning and lightweight experiments.
#
# [Graphics idea: Side by side comparison of Jupyter and Colab features]

# %% [markdown]
# ## Understanding the Parts of a Notebook
# A notebook is a sequence of **cells**. There are two basic types:
#
# 1. **Markdown cells** for text, equations, images, and descriptions.
# 2. **Code cells** for executable Python code.
#
# Running cells updates the notebook state. Variables defined earlier remain available later.
#
# [Graphics idea: screenshot mockup showing markdown vs code cells, visually highlighted]

# %% [markdown]
# ### Markdown Example
# Markdown lets us write formatted text:
# - Bold and italics
# - Headings
# - Lists (like this one)
#
# It can also display mathematics:
# $I(t) = I_0 e^{kt}$
# and render images.

# %%
# This is a code cell. Run me with Shift+Enter.
print("You just executed Python code inside a notebook.")
# Out:
# You just executed Python code inside a notebook.

# %% [markdown]
# ## Thinking Like a Computer
# Programming requires a shift in perspective. Humans fill in gaps automatically. Computers do not. They follow each instruction literally.
#
# Consider the instruction: *"Find the average of these numbers."* A computer needs exact steps:
# 1. Add the numbers.
# 2. Count how many there are.
# 3. Divide the total by the count.
#
# [Graphics idea: cartoon of a robot misinterpreting vague instructions]

# %% [markdown]
# ## Algorithms as Recipes
# A recipe tells you precisely what to do at each step. Algorithms are no different. Good programming means writing clear procedures for the computer.
#
# Let's warm up with our first interactions.

# %%
print("Hello from Python!")
# Out:
# Hello from Python!

# %% [markdown]
# ## Variables and Basic Operations
# Variables let us store information. They act as labeled containers.
#
# Python supports arithmetic directly:

# %%
a = 10
b = 4
print("a + b =", a + b)
print("a * b =", a * b)
print("a / b =", a / b)
# Out:
# a + b = 14
# a * b = 40
# a / b = 2.5

# %% [markdown]
# [Graphics idea: diagram showing variable names pointing to stored values in boxes]
#
# Try modifying `a` and `b` above and re-running the cell.

# %% [markdown]
# ## Numbers vs Strings
# Numbers behave mathematically. Strings behave like text. Python distinguishes them.
#
# For example:

# %%
number = 5
text = "5"

print(number * 3)    # mathematical multiplication
print(text * 3)      # string repetition
# Out:
# 15
# 555

# %% [markdown]
# ## Small Interactive Exercise
# Compute the area of a rectangle. Modify the code below to use different dimensions.

# %%
length = 5
width = 2
area = length * width
print("Area is", area)
# Out:
# Area is 10

# %% [markdown]
# ## Introducing a Biological Dataset
# We will create a synthetic OD (optical density) growth curve. This models how bacterial cultures grow over time.
#
# [Graphics idea: conceptual diagram of exponential bacterial growth]

# %%
import numpy as np

time = np.array([0, 1, 2, 3, 4, 5, 6, 7])
od = np.array([0.05, 0.06, 0.08, 0.12, 0.20, 0.33, 0.52, 0.82])

time, od
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]),
#  array([0.05, 0.06, 0.08, 0.12, 0.2 , 0.33, 0.52, 0.82]))

# %% [markdown]
# ### Inspecting the Data
# We can ask basic questions about the dataset.

# %%
print("Time points:", time)
print("OD values: ", od)
print("Length of dataset:", len(time))
# Out:
# Time points: [0 1 2 3 4 5 6 7]
# OD values:  [0.05 0.06 0.08 0.12 0.2  0.33 0.52 0.82]
# Length of dataset: 8

# %% [markdown]
# ## Visualizing the Growth Curve
# Data becomes meaningful when visualized. We'll use matplotlib for plotting.
#
# [Graphics idea: high quality OD curve plot with labeled axes]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,4))
plt.plot(time, od, marker='o', linestyle='-', color='navy')
plt.xlabel('Time (hours)')
plt.ylabel('Optical Density (OD)')
plt.title('Synthetic Bacterial Growth Curve')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Adding Mathematical Transformations
# Let's compute the fold increase in OD relative to the starting point.

# %%
fold = od / od[0]
fold
# Out:
# array([ 1. ,  1.2,  1.6,  2.4,  4. ,  6.6, 10.4, 16.4])

# %% [markdown]
# Plotting the fold increase helps visualize early growth.

# %%
plt.figure(figsize=(7,4))
plt.plot(time, fold, marker='s')
plt.xlabel('Time (hours)')
plt.ylabel('Fold Increase')
plt.title('Growth Fold Change Over Time')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Loading Data from a File
# In the next lecture we will work with external data files. For now, here is the basic idea:
# ```python
# data = np.loadtxt('growth_curve.txt')
# time = data[:,0]
# od = data[:,1]
# ```
# [Graphics idea: small icon of a .txt file flowing into a notebook]

# %% [markdown]
# ## Comments Make Code Understandable
# A comment begins with `#` and is ignored by Python. Use them to explain logic.

# %%
# Compute the doubling time approximately
approx_doubling_time = time[np.argmax(od > 2*od[0])] if np.any(od > 2*od[0]) else None
approx_doubling_time
# Out:
# np.int64(3)

# %% [markdown]
# ## Errors and How to Read Them
# Let's intentionally generate an error and learn from the traceback.

# %%
print(undefined_variable_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(undefined_variable_name)
#
# NameError: name 'undefined_variable_name' is not defined

# %% [markdown]
# [Graphics idea: annotated traceback screenshot highlighting the variable name error]

# %% [markdown]
# ### What the Error Message Tells You
# - The type of error
# - The line where it occurred
# - A descriptive message
#
# Debugging is a core skill. Errors are not failures; they are feedback.

# %% [markdown]
# ## Debugging with AI Tools
# AI can help interpret errors and suggest fixes. You can paste a traceback into ChatGPT and ask what might be wrong.

# %% [markdown]
# ## Guided Debugging Activity
# Below is broken code. Fix it.

# %%
# Intended: compute OD squared for each value
odsq = od ** 2
print(od_square)   # wrong variable name

# %% [markdown]
# Try fixing the variable name and re-run the cell.
